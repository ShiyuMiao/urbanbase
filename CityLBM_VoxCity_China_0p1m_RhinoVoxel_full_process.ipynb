# %% [markdown]
# # CityLBM VoxCity China 0.1 m Rhino Voxel Full Process
#
# This notebook is the single paper-ready entry point for the local project. It executes the China-oriented data source registry, OSM/local fallback fusion, CRS audit, 0.1 m sparse voxelization, Rhino 3DM export, artifact mapping, provenance, quality audit, figures, and detailed documentation generation. All outputs are written under `outputs_citylbm_voxel_china/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC = PROJECT_ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from china_voxel_pipeline import RunConfig, run_pipeline

config = RunConfig(
    site_name='dut_west_campus_lingxi_library_500m_0p1m',
    site_name_cn='大连理工大学西部校区令希图书馆500m AOI',
    center_lat=38.8831553,
    center_lon=121.5120457,
    half_size_m=250.0,
    buffer_m=0.0,
    voxel_size_m=0.1,
    vertical_extent_m=80.0,
    allow_resolution_fallback=False,
    dem_source='aws_terrarium',
    dem_tile_zoom=14,
)

report = run_pipeline(config)
print('Notebook pipeline finished successfully')
print('Rhino:', 'outputs_citylbm_voxel_china/05_rhino/final_city_voxel_0p1m.3dm')
print('Artifact count:', report.get('artifact_count'))

# %% [markdown]
# ## Verification checklist
#
# The execution report, artifact mapping, provenance, data quality audit, and detailed process document are generated by the code cell above. The external runner saves an executed copy of this notebook in `outputs_citylbm_voxel_china/12_logs/`.
