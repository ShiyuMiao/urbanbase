# %% [markdown]
# # 05 Heat-wind compound risk\n\nGoal: compute first-phase heat risk, low-ventilation risk, exposure, and compound heat-wind risk. This is not a full multi-hazard model.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / 'src').exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))
from urban_morphology.paths import default_paths
from urban_morphology.risk import compute_heat_wind_risk
paths = default_paths(PROJECT_ROOT)
summary = compute_heat_wind_risk(paths)
summary
